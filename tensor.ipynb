# %%
import torch
tensor = torch.randn(5, 4)
print("Original Tensor:\n", tensor)
print("\nMean:", tensor.mean())
print("Max:", tensor.max())
print("Standard Deviation:", tensor.std())
reshaped_tensor = tensor.reshape(4, 5)
print("\nReshaped Tensor (4, 5):\n", reshaped_tensor)
# Out:
# Original Tensor:
#  tensor([[-1.2901, -0.2282, -0.3754, -0.3586],
#         [ 0.0351, -0.6447,  0.8850,  0.3493],
#         [ 2.0069, -0.2330,  1.2100,  0.9190],
#         [ 1.4617,  0.4997,  0.5232, -0.4856],
#         [-0.2862, -0.7320, -0.3847,  0.3451]])
#
# Mean: tensor(0.1608)
# Max: tensor(2.0069)
# Standard Deviation: tensor(0.8260)
#
# Reshaped Tensor (4, 5):
#  tensor([[-1.2901, -0.2282, -0.3754, -0.3586,  0.0351],
#         [-0.6447,  0.8850,  0.3493,  2.0069, -0.2330],
#         [ 1.2100,  0.9190,  1.4617,  0.4997,  0.5232],
#         [-0.4856, -0.2862, -0.7320, -0.3847,  0.3451]])
